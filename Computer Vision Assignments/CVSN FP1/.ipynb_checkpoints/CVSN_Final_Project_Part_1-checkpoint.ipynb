# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import seaborn as sns
# %matplotlib inline

np.random.seed(2)

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import itertools

from keras.utils.np_utils import to_categorical # convert to one-hot-encoding
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, AveragePooling2D
from keras.optimizers import RMSprop, Adam
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ReduceLROnPlateau
from keras.losses import categorical_crossentropy

sns.set(style='white', context='notebook', palette='deep')

# %%
from keras.datasets import fashion_mnist

(X_train, y_train), (X_test, y_test) = fashion_mnist.load_data()

# %%
X_train_flattened = np.empty([X_train.shape[0], X_train.shape[1]*X_train.shape[2]], dtype=int)
X_test_flattened = np.empty([X_test.shape[0], X_test.shape[1]*X_test.shape[2]], dtype=int)

for i in range(X_train.shape[0]):
    X_train_flattened[i] = X_train[i].flatten()
    
for i in range(X_test.shape[0]):
    X_test_flattened[i] = X_test[i].flatten()

# %%
df_train = pd.DataFrame(data=X_train_flattened[0:,0:],
                        index=[i for i in range(X_train_flattened.shape[0])],
                        columns=['pixel'+str(i) for i in range(X_train_flattened.shape[1])])
df_train_y = pd.DataFrame(y_train, dtype=int)
train_y = df_train_y[0]

df_test = pd.DataFrame(data=X_test_flattened[0:,0:],
                        index=[i for i in range(X_test_flattened.shape[0])],
                        columns=['pixel'+str(i) for i in range(X_test_flattened.shape[1])]) 
df_test_y = pd.DataFrame(y_test, dtype=int)
test_y = df_test_y[0]

# %%
g = sns.countplot(train_y)
train_y.value_counts()
# Out:
# 9    6000
# 8    6000
# 7    6000
# 6    6000
# 5    6000
# 4    6000
# 3    6000
# 2    6000
# 1    6000
# 0    6000
# Name: 0, dtype: int64

# %%
df_train = df_train/255.0
df_test = df_test/255.0

df_train = df_train.values.reshape(-1,28,28,1)
df_test = df_test.values.reshape(-1,28,28,1)

# %%
train_y = to_categorical(train_y, num_classes=10)
test_y = to_categorical(test_y, num_classes=10)

# %% [markdown]
# #Neural Network Architecture

# %%
model = Sequential()

model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu', input_shape = (28,28,1)))
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(AveragePooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))


model.add(Conv2D(filters = 64, kernel_size = (3,3),padding = 'Same', 
                 activation ='relu'))
model.add(Conv2D(filters = 64, kernel_size = (3,3),padding = 'Same', 
                 activation ='relu'))
model.add(AveragePooling2D(pool_size=(2,2), strides=(2,2)))
model.add(Dropout(0.25))

model.add(Conv2D(filters = 128, kernel_size = (3,3),padding = 'Same', 
                 activation ='relu'))
model.add(Conv2D(filters = 128, kernel_size = (3,3),padding = 'Same', 
                 activation ='relu'))
model.add(AveragePooling2D(pool_size=(2,2), strides=(2,2)))
model.add(Dropout(0.4))


model.add(Flatten())
model.add(Dense(512, activation = "relu"))
model.add(Dropout(0.3))
model.add(Dense(10, activation = "softmax"))

# %%
#loss = categorical_crossentropy()
optimizer = Adam()

# %%
model.compile(loss = "categorical_crossentropy", optimizer = optimizer ,metrics = ['accuracy'])

# %%
datagen = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        rotation_range=10,  # randomly rotate images in the range (degrees, 0 to 180)
        zoom_range = 0.1, # Randomly zoom image 
        width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)
        horizontal_flip=False,  # randomly flip images
        vertical_flip=False)  # randomly flip images


datagen.fit(df_train)

# %%
epochs = 50
batch_size = 256

# %%
learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', 
                                            patience=3, 
                                            verbose=1, 
                                            factor=0.5, 
                                            min_lr=0.0000001)

# %%
history = model.fit_generator(datagen.flow(df_train, train_y, batch_size=batch_size),
                              epochs = epochs, validation_data = (df_test, test_y),
                              verbose = 2, steps_per_epoch= df_train.shape[0] // batch_size
                              , callbacks=[learning_rate_reduction])
# Out:
# Epoch 1/50
#  - 14s - loss: 0.8801 - accuracy: 0.6658 - val_loss: 0.5741 - val_accuracy: 0.7730
# Epoch 2/50
#  - 13s - loss: 0.5696 - accuracy: 0.7786 - val_loss: 0.4614 - val_accuracy: 0.8235
# Epoch 3/50
#  - 13s - loss: 0.4918 - accuracy: 0.8117 - val_loss: 0.3968 - val_accuracy: 0.8492
# Epoch 4/50
#  - 14s - loss: 0.4434 - accuracy: 0.8311 - val_loss: 0.3516 - val_accuracy: 0.8660
# Epoch 5/50
#  - 14s - loss: 0.4064 - accuracy: 0.8464 - val_loss: 0.3174 - val_accuracy: 0.8825
# Epoch 6/50
#  - 13s - loss: 0.3874 - accuracy: 0.8524 - val_loss: 0.3141 - val_accuracy: 0.8840
# Epoch 7/50
#  - 13s - loss: 0.3612 - accuracy: 0.8639 - val_loss: 0.2874 - val_accuracy: 0.8915
# Epoch 8/50
#  - 13s - loss: 0.3459 - accuracy: 0.8702 - val_loss: 0.2732 - val_accuracy: 0.8956
# Epoch 9/50
#  - 13s - loss: 0.3334 - accuracy: 0.8747 - val_loss: 0.2838 - val_accuracy: 0.8923
# Epoch 10/50
#  - 14s - loss: 0.3253 - accuracy: 0.8787 - val_loss: 0.2553 - val_accuracy: 0.9054
# Epoch 11/50
#  - 14s - loss: 0.3182 - accuracy: 0.8809 - val_loss: 0.2530 - val_accuracy: 0.9041
# Epoch 12/50
#  - 14s - loss: 0.3075 - accuracy: 0.8847 - val_loss: 0.2558 - val_accuracy: 0.9082
# Epoch 13/50
#  - 14s - loss: 0.3053 - accuracy: 0.8853 - val_loss: 0.2473 - val_accuracy: 0.9097
# Epoch 14/50
#  - 14s - loss: 0.2932 - accuracy: 0.8899 - val_loss: 0.2514 - val_accuracy: 0.9071
# Epoch 15/50
#  - 14s - loss: 0.2936 - accuracy: 0.8901 - val_loss: 0.2447 - val_accuracy: 0.9094
# Epoch 16/50
#  - 13s - loss: 0.2827 - accuracy: 0.8951 - val_loss: 0.2396 - val_accuracy: 0.9131
# Epoch 17/50
#  - 13s - loss: 0.2821 - accuracy: 0.8942 - val_loss: 0.2303 - val_accuracy: 0.9143
# Epoch 18/50
#  - 14s - loss: 0.2778 - accuracy: 0.8970 - val_loss: 0.2398 - val_accuracy: 0.9101
# Epoch 19/50
#  - 14s - loss: 0.2727 - accuracy: 0.8980 - val_loss: 0.2343 - val_accuracy: 0.9145
# Epoch 20/50
#  - 14s - loss: 0.2699 - accuracy: 0.8982 - val_loss: 0.2275 - val_accuracy: 0.9160
# Epoch 21/50
#  - 13s - loss: 0.2657 - accuracy: 0.9019 - val_loss: 0.2235 - val_accuracy: 0.9154
# Epoch 22/50
#  - 13s - loss: 0.2633 - accuracy: 0.9024 - val_loss: 0.2356 - val_accuracy: 0.9135
# Epoch 23/50
#  - 13s - loss: 0.2590 - accuracy: 0.9045 - val_loss: 0.2181 - val_accuracy: 0.9173
# Epoch 24/50
#  - 13s - loss: 0.2518 - accuracy: 0.9059 - val_loss: 0.2220 - val_accuracy: 0.9173
# Epoch 25/50
#  - 13s - loss: 0.2524 - accuracy: 0.9053 - val_loss: 0.2188 - val_accuracy: 0.9178
# Epoch 26/50
#  - 13s - loss: 0.2533 - accuracy: 0.9047 - val_loss: 0.2059 - val_accuracy: 0.9262
# Epoch 27/50
#  - 13s - loss: 0.2456 - accuracy: 0.9073 - val_loss: 0.2079 - val_accuracy: 0.9235
# Epoch 28/50
#  - 13s - loss: 0.2448 - accuracy: 0.9082 - val_loss: 0.2069 - val_accuracy: 0.9231
# Epoch 29/50
#  - 13s - loss: 0.2422 - accuracy: 0.9102 - val_loss: 0.2048 - val_accuracy: 0.9270
# Epoch 30/50
#  - 13s - loss: 0.2386 - accuracy: 0.9108 - val_loss: 0.2095 - val_accuracy: 0.9212
# Epoch 31/50
#  - 13s - loss: 0.2367 - accuracy: 0.9116 - val_loss: 0.2098 - val_accuracy: 0.9228
# Epoch 32/50
#  - 13s - loss: 0.2363 - accuracy: 0.9110 - val_loss: 0.2136 - val_accuracy: 0.9219
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 33/50
#  - 13s - loss: 0.2215 - accuracy: 0.9175 - val_loss: 0.1956 - val_accuracy: 0.9286
# Epoch 34/50
#  - 13s - loss: 0.2153 - accuracy: 0.9200 - val_loss: 0.1929 - val_accuracy: 0.9291
# Epoch 35/50
#  - 13s - loss: 0.2156 - accuracy: 0.9188 - val_loss: 0.1952 - val_accuracy: 0.9298
# Epoch 36/50
#  - 13s - loss: 0.2100 - accuracy: 0.9215 - val_loss: 0.1920 - val_accuracy: 0.9309
# Epoch 37/50
#  - 14s - loss: 0.2091 - accuracy: 0.9211 - val_loss: 0.2010 - val_accuracy: 0.9236
# Epoch 38/50
#  - 13s - loss: 0.2057 - accuracy: 0.9238 - val_loss: 0.1951 - val_accuracy: 0.9300
# Epoch 39/50
#  - 13s - loss: 0.2058 - accuracy: 0.9217 - val_loss: 0.1924 - val_accuracy: 0.9301
#
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 40/50
#  - 13s - loss: 0.2021 - accuracy: 0.9246 - val_loss: 0.1916 - val_accuracy: 0.9301
# Epoch 41/50
#  - 13s - loss: 0.1973 - accuracy: 0.9254 - val_loss: 0.1898 - val_accuracy: 0.9322
# Epoch 42/50
#  - 13s - loss: 0.1958 - accuracy: 0.9264 - val_loss: 0.1906 - val_accuracy: 0.9309
# Epoch 43/50
#  - 14s - loss: 0.1935 - accuracy: 0.9261 - val_loss: 0.1919 - val_accuracy: 0.9307
# Epoch 44/50
#  - 13s - loss: 0.1923 - accuracy: 0.9279 - val_loss: 0.1908 - val_accuracy: 0.9320
#
# Epoch 00044: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 45/50
#  - 13s - loss: 0.1893 - accuracy: 0.9291 - val_loss: 0.1967 - val_accuracy: 0.9293
# Epoch 46/50
#  - 13s - loss: 0.1826 - accuracy: 0.9312 - val_loss: 0.1890 - val_accuracy: 0.9309
# Epoch 47/50
#  - 13s - loss: 0.1874 - accuracy: 0.9297 - val_loss: 0.1890 - val_accuracy: 0.9306
#
# Epoch 00047: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 48/50
#  - 13s - loss: 0.1844 - accuracy: 0.9307 - val_loss: 0.1866 - val_accuracy: 0.9337
# Epoch 49/50
#  - 13s - loss: 0.1831 - accuracy: 0.9322 - val_loss: 0.1839 - val_accuracy: 0.9333
# Epoch 50/50
#  - 13s - loss: 0.1811 - accuracy: 0.9315 - val_loss: 0.1838 - val_accuracy: 0.9343

# %%
fig, ax = plt.subplots(2,1)
ax[0].plot(history.history['loss'], color='b', label="Training loss")
ax[0].plot(history.history['val_loss'], color='r', label="validation loss",axes =ax[0])
legend = ax[0].legend(loc='best', shadow=True)

ax[1].plot(history.history['accuracy'], color='b', label="Training accuracy")
ax[1].plot(history.history['val_accuracy'], color='r',label="Validation accuracy")
legend = ax[1].legend(loc='best', shadow=True)

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# Predict the values from the validation dataset
Y_pred = model.predict(df_test)
# Convert predictions classes to one hot vectors 
Y_pred_classes = np.argmax(Y_pred,axis = 1) 
# Convert validation observations to one hot vectors
Y_true = np.argmax(test_y,axis = 1) 
# compute the confusion matrix
confusion_mtx = confusion_matrix(Y_true, Y_pred_classes) 
# plot the confusion matrix
plot_confusion_matrix(confusion_mtx, classes = range(10))

# %%
# Display some error results 

# Errors are difference between predicted labels and true labels
errors = (Y_pred_classes - Y_true != 0)

Y_pred_classes_errors = Y_pred_classes[errors]
Y_pred_errors = Y_pred[errors]
Y_true_errors = Y_true[errors]
X_val_errors = df_test[errors]

def display_errors(errors_index,img_errors,pred_errors, obs_errors):
    """ This function shows 6 images with their predicted and real labels"""
    n = 0
    nrows = 3
    ncols = 4
    fig, ax = plt.subplots(nrows,ncols,sharex=True,sharey=True)
    for row in range(nrows):
        for col in range(ncols):
            error = errors_index[n]
            ax[row,col].imshow((img_errors[error]).reshape((28,28)))
            ax[row,col].set_title("Predicted label :{}\nTrue label :{}".format(pred_errors[error],obs_errors[error]))
            n += 1

# Probabilities of the wrong predicted numbers
Y_pred_errors_prob = np.max(Y_pred_errors,axis = 1)

# Predicted probabilities of the true values in the error set
true_prob_errors = np.diagonal(np.take(Y_pred_errors, Y_true_errors, axis=1))

# Difference between the probability of the predicted label and the true label
delta_pred_true_errors = Y_pred_errors_prob - true_prob_errors

# Sorted list of the delta prob errors
sorted_dela_errors = np.argsort(delta_pred_true_errors)

# Top 6 errors 
most_important_errors = sorted_dela_errors[-12:]

# Show the top 6 errors
display_errors(most_important_errors, X_val_errors, Y_pred_classes_errors, Y_true_errors)
